# %%
import pandas as pd
import ta
import matplotlib.pyplot as plt

# Load data
df = pd.read_csv('data/AAPL.csv', sep=',')

# Clean nan values

# df = ta.utils.dropna(df)

# %%
# df = ta.utils.dropna(df)

print(df.columns)
# Out:
# Index(['Unnamed: 0', 'Date', 'Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
df = ta.add_all_ta_features(df, "Open", "High", "Low", "Close", "Volume", fillna=True)
# Out:
# C:\Users\amit\.conda\envs\tfp3.6\lib\site-packages\ta\trend.py:543: RuntimeWarning: invalid value encountered in double_scalars
#   dip[i] = 100 * (self._dip[i]/self._trs[i])
# C:\Users\amit\.conda\envs\tfp3.6\lib\site-packages\ta\trend.py:547: RuntimeWarning: invalid value encountered in double_scalars
#   din[i] = 100 * (self._din[i]/self._trs[i])

# %%
print(df.columns)
print(len(df.columns))
# Out:
# Index(['Unnamed: 0', 'Date', 'Open', 'High', 'Low', 'Close', 'Volume',
#        'volume_adi', 'volume_obv', 'volume_cmf', 'volume_fi', 'volume_em',
#        'volume_sma_em', 'volume_vpt', 'volume_nvi', 'volatility_atr',
#        'volatility_bbh', 'volatility_bbl', 'volatility_bbm', 'volatility_bbhi',
#        'volatility_bbli', 'volatility_kcc', 'volatility_kch', 'volatility_kcl',
#        'volatility_kchi', 'volatility_kcli', 'volatility_dcl',
#        'volatility_dch', 'volatility_dchi', 'volatility_dcli', 'trend_macd',
#        'trend_macd_signal', 'trend_macd_diff', 'trend_ema_fast',
#        'trend_ema_slow', 'trend_adx', 'trend_adx_pos', 'trend_adx_neg',
#        'trend_vortex_ind_pos', 'trend_vortex_ind_neg', 'trend_vortex_ind_diff',
#        'trend_trix', 'trend_mass_index', 'trend_cci', 'trend_dpo', 'trend_kst',
#        'trend_kst_sig', 'trend_kst_diff', 'trend_ichimoku_a',
#        'trend_ichimoku_b', 'trend_visual_ichimoku_a',
# ...

# %%
df.head()
# Out:
#    Unnamed: 0      Date   Open   High    Low  Close      Volume    volume_adi  \
# 0         0.0  1/2/1998  13.63  16.25  13.50  16.25   6411700.0  6.411700e+06
# 1         1.0  1/5/1998  16.50  16.56  15.19  15.88   5820300.0  6.454184e+06
# 2         2.0  1/6/1998  15.94  20.00  14.75  18.94  16182800.0  1.610222e+07
# 3         3.0  1/7/1998  18.81  19.00  17.31  17.50   9300200.0  8.893184e+06
# 4         4.0  1/8/1998  17.44  18.62  16.94  18.19   6910900.0  1.226636e+07
#
#    volume_obv  volume_cmf  ...  momentum_uo  momentum_stoch  \
# 0   6411700.0    1.000000  ...     1.992956      100.000000
# 1    591400.0    0.527647  ...     2.468498       77.777778
# 2  16774200.0    0.566684  ...     5.276406       83.692308
# 3   7474000.0    0.235800  ...     5.345327       61.538462
# 4  14384900.0    0.274871  ...     6.129372       72.153846
#
#    momentum_stoch_signal  momentum_wr  momentum_ao  momentum_kama  \
# ...
