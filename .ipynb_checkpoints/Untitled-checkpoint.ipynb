# %%
import numpy as np

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common.vec_env import DummyVecEnv
from stable_baselines import PPO2

from env.StockTradingEnv import StockTradingEnv

from env.StockTradingTestingEnv import StockTradingTestingEnv
import pandas as pd
import matplotlib.pyplot as plt

df_train = pd.read_csv('./data/AAPL.csv')
df_test = pd.read_csv('./data/IBM.csv')

# %%
df_train.head()
# Out:
#    Unnamed: 0      Date   Open   High    Low  Close      Volume
# 0         0.0  1/2/1998  13.63  16.25  13.50  16.25   6411700.0
# 1         1.0  1/5/1998  16.50  16.56  15.19  15.88   5820300.0
# 2         2.0  1/6/1998  15.94  20.00  14.75  18.94  16182800.0
# 3         3.0  1/7/1998  18.81  19.00  17.31  17.50   9300200.0
# 4         4.0  1/8/1998  17.44  18.62  16.94  18.19   6910900.0

# %%
df_test.head()
# Out:
#    Unnamed: 0       Date      Open      High       Low     Close   Volume
# 0           0  9/16/2013  163.6612  164.5990  162.7402  163.1965  3906986
# 1           1  9/17/2013  163.4246  164.0414  162.0812  162.3600  2931628
# 2           2  9/18/2013  162.7318  164.6666  162.2248  164.2695  3841826
# 3           3  9/19/2013  164.0667  164.6666  163.2556  163.3993  3178067
# 4           4  9/20/2013  163.8809  164.2779  160.5519  160.5519  8525983

# %%
df_train = df_train.dropna()
df_test = df_test.dropna()

# %%
df_train = df_train.drop("Unnamed: 0", axis=1)

df_test = df_test.drop("Unnamed: 0", axis=1)

# %%
df_test.describe
# Out:
# <bound method NDFrame.describe of            Date      Open      High       Low     Close   Volume
# 0     9/16/2013  163.6612  164.5990  162.7402  163.1965  3906986
# 1     9/17/2013  163.4246  164.0414  162.0812  162.3600  2931628
# 2     9/18/2013  162.7318  164.6666  162.2248  164.2695  3841826
# 3     9/19/2013  164.0667  164.6666  163.2556  163.3993  3178067
# 4     9/20/2013  163.8809  164.2779  160.5519  160.5519  8525983
# ...         ...       ...       ...       ...       ...      ...
# 1254   9/7/2018  145.9400  146.5031  145.1200  145.4500  4693127
# 1255  9/10/2018  146.6000  147.3000  145.5600  145.6500  3618209
# 1256  9/11/2018  146.0000  146.9900  145.2500  146.4900  3374774
# 1257  9/12/2018  146.3700  147.9800  146.0300  146.5700  4506679
# 1258  9/13/2018  147.3500  149.0000  147.1179  148.9500  5346540
#
# [1259 rows x 6 columns]>

# %%
env_train = DummyVecEnv([lambda: StockTradingEnv(df_train)])
env_test = DummyVecEnv([lambda: StockTradingTestingEnv(df_test)])

# %%
df_test.isnull().values.any()
# Out:
# False

# %%
model = PPO2(MlpPolicy, env_train, verbose=1,tensorboard_log="./PPO2_tensorboard/")
# model.learn(total_timesteps=100000)
# model.save("latest_withdata.pkl")
model.load("latest_withdata.pkl")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-66-6c4714c25331> in <module>
# ----> 1 model = PPO2(MlpLstmPolicy, env_train, verbose=1,tensorboard_log="./PPO2_tensorboard/")
#       2 # model.learn(total_timesteps=100000)
#       3 # model.save("latest_withdata.pkl")
#       4 model.load("latest_withdata.pkl")
#       5
#
# ~\.conda\envs\tfp3.6\lib\site-packages\stable_baselines\ppo2\ppo2.py in __init__(self, policy, env, gamma, n_steps, ent_coef, learning_rate, vf_coef, max_grad_norm, lam, nminibatches, noptepochs, cliprange, cliprange_vf, verbose, tensorboard_log, _init_setup_model, policy_kwargs, full_tensorboard_log)
#      98
#      99         if _init_setup_model:
# --> 100             self.setup_model()
#     101
#     102     def _get_pretrain_placeholders(self):
#
# ~\.conda\envs\tfp3.6\lib\site-packages\stable_baselines\ppo2\ppo2.py in setup_model(self)
#     125                 n_batch_train = None
#     126                 if issubclass(self.policy, RecurrentActorCriticPolicy):
# --> 127                     assert self.n_envs % self.nminibatches == 0, "For recurrent policies, "\
#     128                         "the number of environments run in parallel should be a multiple of nminibatches."
#     129                     n_batch_step = self.n_envs
#
# AssertionError: For recurrent policies, the number of environments run in parallel should be a multiple of nminibatches.

# %%
obs = env_test.reset()

# %%
frame = np.array([
            df_test.loc[0: 0 +
                        5, 'Open'].values / 100,
            df_test.loc[0: 0 +
                        5, 'High'].values / 100,
            df_test.loc[0: 0 +
                        5, 'Low'].values / 100,
            df_test.loc[0: 0 +
                        5, 'Close'].values / 100,
            df_test.loc[0: 0 +
                        5, 'Volume'].values / 200,
        ])

# %%
frame

# %%
balance_plot = list()
share_plot = list()
profit_plot = list()

obs_plot = list()
n = 200
for i in range(n):
    action, _states = model.predict(obs)
    obs, rewards, done, info = env_test.step(action)
    obs_plot.append(obs)

    balance, profit, share = env_test.render()
    balance_plot.append(balance)
    share_plot.append(share)
    profit_plot.append(profit)
    if done:
        break

# %%
plt.plot(np.array(profit_plot).ravel(),color='red')
plt.show()

# %%
plt.plot(np.array(share_plot).ravel(), linewidth=1)
plt.show()

# %%
df_test[:n].plot(x='Date', y=['Open'], figsize=(10,5), grid=True)
plt.show()
